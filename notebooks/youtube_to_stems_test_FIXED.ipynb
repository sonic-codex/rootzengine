# %% [markdown]
# # YouTube to Reggae Stem Splitter
# Download a reggae song from YouTube and split it into stems (vocals, drums, bass, other).

# %%
# !pip install demucs==4.0.0
# Out:
# Requirement already satisfied: demucs==4.0.0 in /usr/local/lib/python3.11/dist-packages (4.0.0)
# Requirement already satisfied: dora-search in /usr/local/lib/python3.11/dist-packages (from demucs==4.0.0) (0.1.12)
# Requirement already satisfied: diffq>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from demucs==4.0.0) (0.2.4)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from demucs==4.0.0) (0.8.1)
# Requirement already satisfied: julius>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from demucs==4.0.0) (0.2.7)
# Requirement already satisfied: lameenc>=1.2 in /usr/local/lib/python3.11/dist-packages (from demucs==4.0.0) (1.8.1)
# Requirement already satisfied: openunmix in /usr/local/lib/python3.11/dist-packages (from demucs==4.0.0) (1.3.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from demucs==4.0.0) (6.0.2)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from demucs==4.0.0) (2.6.0+cu124)
# Requirement already satisfied: torchaudio>=0.8 in /usr/local/lib/python3.11/dist-packages (from demucs==4.0.0) (2.6.0+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from demucs==4.0.0) (4.67.1)
# Requirement already satisfied: Cython in /usr/local/lib/python3.11/dist-packages (from diffq>=0.2.1->demucs==4.0.0) (3.0.12)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from diffq>=0.2.1->demucs==4.0.0) (2.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->demucs==4.0.0) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->demucs==4.0.0) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->demucs==4.0.0) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->demucs==4.0.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->demucs==4.0.0) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->demucs==4.0.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->demucs==4.0.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->demucs==4.0.0) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->demucs==4.0.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->demucs==4.0.0) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->demucs==4.0.0) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->demucs==4.0.0) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->demucs==4.0.0) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->demucs==4.0.0) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->demucs==4.0.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->demucs==4.0.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->demucs==4.0.0) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->demucs==4.0.0) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->demucs==4.0.0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->demucs==4.0.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.1->demucs==4.0.0) (1.3.0)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.11/dist-packages (from dora-search->demucs==4.0.0) (2.3.0)
# Requirement already satisfied: retrying in /usr/local/lib/python3.11/dist-packages (from dora-search->demucs==4.0.0) (1.3.4)
# Requirement already satisfied: submitit in /usr/local/lib/python3.11/dist-packages (from dora-search->demucs==4.0.0) (1.5.2)
# Requirement already satisfied: treetable in /usr/local/lib/python3.11/dist-packages (from dora-search->demucs==4.0.0) (0.2.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.1->demucs==4.0.0) (3.0.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.11/dist-packages (from omegaconf->dora-search->demucs==4.0.0) (4.9.3)
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from retrying->dora-search->demucs==4.0.0) (1.17.0)
# Requirement already satisfied: cloudpickle>=1.2.1 in /usr/local/lib/python3.11/dist-packages (from submitit->dora-search->demucs==4.0.0) (3.1.1)

# %%
# Install yt-dlp and spleeter if not already installed
from demucs.apply import apply_model

# %%
import os
import subprocess
from yt_dlp import YoutubeDL

# CONFIG
video_url = "https://youtu.be/69RdQFDuYPI?feature=shared"
download_dir = "test_stems"
stem_dir = os.path.join(download_dir, "stems")
os.makedirs(download_dir, exist_ok=True)

# Step 1: Download MP3
print("Downloading MP3...")
ydl_opts = {
    "format": "bestaudio/best",
    "outtmpl": os.path.join(download_dir, "%(title)s.%(ext)s"),
    "postprocessors": [{
        "key": "FFmpegExtractAudio",
        "preferredcodec": "mp3",
        "preferredquality": "192"
    }]
}
with YoutubeDL(ydl_opts) as ydl:
    ydl.download([video_url])
# Out:
# Downloading MP3...
# [youtube] Extracting URL: https://youtu.be/69RdQFDuYPI?feature=shared
# [youtube] 69RdQFDuYPI: Downloading webpage
# [youtube] 69RdQFDuYPI: Downloading tv client config
# [youtube] 69RdQFDuYPI: Downloading player 20830619
# [youtube] 69RdQFDuYPI: Downloading tv player API JSON
# [youtube] 69RdQFDuYPI: Downloading ios player API JSON
# [youtube] 69RdQFDuYPI: Downloading m3u8 information
# [info] 69RdQFDuYPI: Downloading 1 format(s): 251
# [download] Destination: test_stems/Bob Marley - Is This Love (Official Music Video).webm
# [download] 100% of    3.89MiB in 00:00:00 at 26.23MiB/s
# [ExtractAudio] Destination: test_stems/Bob Marley - Is This Love (Official Music Video).mp3
# Deleting original file test_stems/Bob Marley - Is This Love (Official Music Video).webm (pass -k to keep)

# %%
import os
import subprocess
from yt_dlp import YoutubeDL

# CONFIG
video_url = "https://youtu.be/b0Tk-FoiX_0?feature=shared"
download_dir = "test_stems"
stem_dir = os.path.join(download_dir, "stems")
os.makedirs(download_dir, exist_ok=True)

# Step 1: Download MP3
print("Downloading MP3...")
ydl_opts = {
    "format": "bestaudio/best",
    "outtmpl": os.path.join(download_dir, "%(title)s.%(ext)s"),
    "postprocessors": [{
        "key": "FFmpegExtractAudio",
        "preferredcodec": "mp3",
        "preferredquality": "192"
    }]
}
with YoutubeDL(ydl_opts) as ydl:
    ydl.download([video_url])
# Out:
# Downloading MP3...
# [youtube] Extracting URL: https://youtu.be/b0Tk-FoiX_0?feature=shared
# [youtube] b0Tk-FoiX_0: Downloading webpage
# [youtube] b0Tk-FoiX_0: Downloading tv client config
# [youtube] b0Tk-FoiX_0: Downloading player 20830619
# [youtube] b0Tk-FoiX_0: Downloading tv player API JSON
# [youtube] b0Tk-FoiX_0: Downloading ios player API JSON
# [youtube] b0Tk-FoiX_0: Downloading m3u8 information
# [info] b0Tk-FoiX_0: Downloading 1 format(s): 251
# [download] Destination: test_stems/Small Axe (1973) - Bob Marley & The Wailers.webm
# [download] 100% of    3.70MiB in 00:00:00 at 24.82MiB/s
# [ExtractAudio] Destination: test_stems/Small Axe (1973) - Bob Marley & The Wailers.mp3
# Deleting original file test_stems/Small Axe (1973) - Bob Marley & The Wailers.webm (pass -k to keep)

# %%
import os
import subprocess
from yt_dlp import YoutubeDL

# CONFIG
video_url = "https://youtu.be/LRxYg_20oPg?feature=shared"
download_dir = "test_stems"
stem_dir = os.path.join(download_dir, "stems")
os.makedirs(download_dir, exist_ok=True)

# Step 1: Download MP3
print("Downloading MP3...")
ydl_opts = {
    "format": "bestaudio/best",
    "outtmpl": os.path.join(download_dir, "%(title)s.%(ext)s"),
    "postprocessors": [{
        "key": "FFmpegExtractAudio",
        "preferredcodec": "mp3",
        "preferredquality": "192"
    }]
}
with YoutubeDL(ydl_opts) as ydl:
    ydl.download([video_url])
# Out:
# Downloading MP3...
# [youtube] Extracting URL: https://youtu.be/LRxYg_20oPg?feature=shared
# [youtube] LRxYg_20oPg: Downloading webpage
# [youtube] LRxYg_20oPg: Downloading tv client config
# [youtube] LRxYg_20oPg: Downloading player 20830619
# [youtube] LRxYg_20oPg: Downloading tv player API JSON
# [youtube] LRxYg_20oPg: Downloading ios player API JSON
# [youtube] LRxYg_20oPg: Downloading m3u8 information
# [info] LRxYg_20oPg: Downloading 1 format(s): 251
# [download] Destination: test_stems/Steel Pulse- Your House.webm
# [download] 100% of    3.56MiB in 00:00:00 at 25.12MiB/s
# [ExtractAudio] Destination: test_stems/Steel Pulse- Your House.mp3
# Deleting original file test_stems/Steel Pulse- Your House.webm (pass -k to keep)
