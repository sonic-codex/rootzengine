# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install demucs yt-dlp mido scikit-learn ffmpeg-python librosa norbert

# %%
# Set working directory (update your folder path)
import os
os.chdir('/content/drive/MyDrive/RootzEngine/')

# %%
import time
links = ["https://youtube.com/playlist?list=PLRH43FHT5_3gb3tc3NL9pOlnSQcfMGiVb&feature=shared", "https://youtube.com/playlist?list=PLRH43FHT5_3gb3tc3NL9pOlnSQcfMGiVb&feature=shared"]

for url in links:
    # !yt-dlp -x --audio-format mp3 "{url}"
    time.sleep(10)
# Out:
# [youtube:tab] Extracting URL: https://youtube.com/playlist?list=PLRH43FHT5_3gb3tc3NL9pOlnSQcfMGiVb&feature=shared
# [youtube:tab] PLRH43FHT5_3gb3tc3NL9pOlnSQcfMGiVb: Downloading webpage
# [youtube:tab] PLRH43FHT5_3gb3tc3NL9pOlnSQcfMGiVb: Redownloading playlist API JSON with unavailable videos
# [download] Downloading playlist: Roots Reggae Classics
# [youtube:tab] PLRH43FHT5_3gb3tc3NL9pOlnSQcfMGiVb page 1: Downloading API JSON
# [youtube:tab] Playlist Roots Reggae Classics: Downloading 136 items of 136
# [download] Downloading item 1 of 136
# [youtube] Extracting URL: https://www.youtube.com/watch?v=K6oYyG0KcvQ
# [youtube] K6oYyG0KcvQ: Downloading webpage
# WARNING: [youtube] Unable to download webpage: HTTP Error 429: Too Many Requests (caused by <HTTPError 429: Too Many Requests>)
# [youtube] K6oYyG0KcvQ: Downloading tv client config
# [youtube] K6oYyG0KcvQ: Downloading player 20830619
# [youtube] K6oYyG0KcvQ: Downloading tv player API JSON
# ...

# %%
import glob
import os

# Path to your RootzEngine folder containing MP3 files
mp3_folder = "/content/drive/MyDrive/RootzEngine/mp3/*.mp3"

# Loop through all MP3 files and process each with Demucs
for mp3_file in glob.glob(mp3_folder):
    print(f"Processing {mp3_file}...")
    os.system(f'demucs --two-stems=bass "{mp3_file}" -o stems')

# %%
# Convert bass WAV to MIDI
# (add your custom script or commands here)

# %%
# Generate JSON Groove Maps
# (add your custom script or commands here)
